# %% [markdown]
# <a href="https://colab.research.google.com/github/k2moon/ml-hg/blob/main/hg_02_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 훈련 세트와 테스트 세트
# ---
#
# ## 핵심 키워드
# ---
# - 지도 학습
# - 비지도 학습
# - 훈련 세트
# - 테스트 세트

# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/github/rickiepark/hg-mldl/blob/master/2-1.ipynb"><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />구글 코랩에서 실행하기</a>
#   </td>
# </table>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 지도 학습 supervised learning
# ---
# - 지도 학습 알고리즘은 훈련하기 위한 데이터와 정답이 필요
# - 데이터 : 입력 input
# - 정답 : 타깃 target
# - 훈련 데이터 training data : input + target
# - 비지도 학습 알고리즘은 타깃 없이 입력 데이터만 사용 => 데이터를 파악하거나 변형에 사용

# %% [markdown]
# ## 훈련 세트와 테스트 세트
# ---
#
# - 훈련 세트 training set : 훈련에 사용되는 데이터, 문제집
# - 테스트 세트 test set : 평가에 사용되는 데이터, 모의고사

# %% [markdown]
# ### 데이터 준비
# ---
# - http://bit.ly/bream_smelt
# - 샘플 sample : 하나의  데이터
# - 생선 데이터 : 49개의 샘플

# %%
fish_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8, 
                10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
fish_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7, 
                7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
fish_data = [[l, w] for l, w in zip(fish_length, fish_weight)]
fish_target = [1]*35 + [0]*14

# %%
from sklearn.neighbors import KNeighborsClassifier

kn = KNeighborsClassifier()

# %%
print(fish_data[4])
# Out:
# [29.0, 430.0]

# %%
print(fish_data[0:5])
# Out:
# [[25.4, 242.0], [26.3, 290.0], [26.5, 340.0], [29.0, 363.0], [29.0, 430.0]]

# %%
print(fish_data[:5])
# Out:
# [[25.4, 242.0], [26.3, 290.0], [26.5, 340.0], [29.0, 363.0], [29.0, 430.0]]

# %%
print(fish_data[44:])
# Out:
# [[12.2, 12.2], [12.4, 13.4], [13.0, 12.2], [14.3, 19.7], [15.0, 19.9]]

# %%
train_input = fish_data[:35]
train_target = fish_target[:35]

test_input = fish_data[35:]
test_target = fish_target[35:]

# %%
kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 0.0

# %% [markdown]
# > **정확도가 왜 0일까요?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 샘플링 편향 sampling bias
# ---
# - 훈련 세트와 테스트 세트에 샘플이 골고루 섞여 있지 않아 샘플링이 한쪽으로 치우졌다는 의미

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np

# %%
fish_data[:5]
# Out:
# [[25.4, 242.0], [26.3, 290.0], [26.5, 340.0], [29.0, 363.0], [29.0, 430.0]]

# %%
# 리스트 data 넘파이 배열로 변환 => 2차원
input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

# %%
print(input_arr)
# Out:
# [[  25.4  242. ]
#  [  26.3  290. ]
#  [  26.5  340. ]
#  [  29.   363. ]
#  [  29.   430. ]
#  [  29.7  450. ]
#  [  29.7  500. ]
#  [  30.   390. ]
#  [  30.   450. ]
#  [  30.7  500. ]
#  [  31.   475. ]
#  [  31.   500. ]
#  [  31.5  500. ]
#  [  32.   340. ]
#  [  32.   600. ]
#  [  32.   600. ]
#  [  33.   700. ]
#  [  33.   700. ]
#  [  33.5  610. ]
#  [  33.5  650. ]
#  [  34.   575. ]
#  [  34.   685. ]
#  [  34.5  620. ]
#  [  35.   680. ]
#  [  35.   700. ]
#  [  35.   725. ]
#  [  35.   720. ]
#  [  36.   714. ]
#  [  36.   850. ]
#  [  37.  1000. ]
#  [  38.5  920. ]
#  [  38.5  955. ]
#  [  39.5  925. ]
#  [  41.   975. ]
#  [  41.   950. ]
#  [   9.8    6.7]
#  [  10.5    7.5]
#  [  10.6    7. ]
#  [  11.     9.7]
#  [  11.2    9.8]
#  [  11.3    8.7]
#  [  11.8   10. ]
#  [  11.8    9.9]
#  [  12.     9.8]
#  [  12.2   12.2]
#  [  12.4   13.4]
#  [  13.    12.2]
#  [  14.3   19.7]
#  [  15.    19.9]]

# %%
# 49 x 2 2차원
print(input_arr.shape)
# Out:
# (49, 2)

# %% [markdown]
# ### 데이터 섞기
# ---

# %%
# 샘플링을 위해 index shuffle
np.random.seed(42)
index = np.arange(49)
np.random.shuffle(index)

# %%
print(index)
# Out:
# [13 45 47 44 17 27 26 25 31 19 12  4 34  8  3  6 40 41 46 15  9 16 24 33
#  30  0 43 32  5 29 11 36  1 21  2 37 35 23 39 10 22 18 48 20  7 42 14 28
#  38]

# %%
print(input_arr[[1,3]])
# Out:
# [[ 26.3 290. ]
#  [ 29.  363. ]]

# %%
train_input = input_arr[index[:35]]
train_target = target_arr[index[:35]]

# %%
print(input_arr[13], train_input[0])
# Out:
# [ 32. 340.] [ 32. 340.]

# %%
test_input = input_arr[index[35:]]
test_target = target_arr[index[35:]]

# %% [markdown]
# ### 분포 확인
# ---

# %%
# 산포도로 분포 확인

import matplotlib.pyplot as plt

plt.scatter(train_input[:, 0], train_input[:, 1])
plt.scatter(test_input[:, 0], test_input[:, 1])
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %% [markdown]
# ## 두 번째 머신러닝 프로그램

# %%
kn.fit(train_input, train_target)
# Out:
# KNeighborsClassifier()

# %%
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
# array() : 넘파이 배열
kn.predict(test_input)
# Out:
# array([0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 1, 0])

# %%
test_target
# Out:
# array([0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 1, 0])

# %%
type(test_target)
# Out:
# numpy.ndarray

# %% [markdown]
# ## 마무리
# ---
#
# ### 키워드
# ---
#
# - 지도 학습 : 입력과 타깃을 전달하여 모델을 훈련한 다음 새로운 데이터를 예측하는데 활용
# - 비지도 학습 : 타깃 데이터가 없고 따라서 예측하는 것이 아니라 입력 데이터에서 어떤 특징을 찾는 데 주로 활용
# - 훈련 세트 : 모델을 훈련할 때 사용하는 데이터, 보통 클수록 좋으며 데스트 세트를 제외한 모든 데이터를 사용
# - 테스트 세트 : 전체 데이터에서 보통 20 ~ 30% 사용, 전체 데이터가 아주 크다면 1%만 사용해도 충분
